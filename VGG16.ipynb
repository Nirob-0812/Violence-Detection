# %%
from keras.applications.vgg16 import VGG16
from keras.applications.vgg19 import VGG19
from keras.applications.resnet50 import ResNet50
from keras.models import Model
from keras.layers import Dense, LSTM, TimeDistributed, Flatten, Input,GRU
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import numpy as np
import tensorflow as tf
from keras.callbacks import EarlyStopping

def build_model(application,model_layer):
    # Load the model
    base_model = application(weights='imagenet', include_top=False, input_shape=(96, 96, 3))

    # Make the base model non-trainable
    for layer in base_model.layers:
        layer.trainable = False

    # Define the input shape for our final model
    # The shape should be (num_frames, height, width, channels)
    # Replace num_frames with the number of frames in our video data
    input_shape = (16, 96,96, 3)
    model_input = Input(shape=input_shape)

    # Add a TimeDistributed wrapper to handle the time dimension in the video data
    x = TimeDistributed(base_model)(model_input)

    # Flatten the output
    x = TimeDistributed(Flatten())(x)

    # Add an LSTM layer to handle the sequence of features extracted from the frames
    x = model_layer(256)(x)

    # Add a Dense layer for binary classification
    output = Dense(2, activation='softmax')(x)
    return Model(inputs=model_input, outputs=output)

# %%
features,labels=np.load("Features/features_Own96.npy"),np.load("Features/labels_Own96.npy")

# %%
one_hot_encoded_labels = to_categorical(labels)
features_train, features_test, labels_train, labels_test = train_test_split(features, one_hot_encoded_labels, test_size=0.2,
                                                                            shuffle=True, random_state=42)

# %%
# Create a new model
vgg16_model = build_model(VGG16,LSTM)

# %%
early_stopping_callback = EarlyStopping(monitor = 'val_accuracy', patience = 10, restore_best_weights = True)

# Create ReduceLROnPlateau Callback to reduce overfitting by decreasing learning
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',factor=0.6,patience=5,min_lr=0.00005,verbose=1)
 
# Compiling the model 
vgg16_model.compile(loss = 'categorical_crossentropy', optimizer = 'sgd', metrics = ["accuracy"]) 
 
# Fitting the model 
history = vgg16_model.fit(x = features_train, y = labels_train, epochs = 50, batch_size = 10 ,
                                             shuffle = True, validation_split = 0.2, callbacks = [early_stopping_callback,reduce_lr])
# Out:
# Epoch 1/50
# 64/64 [==============================] - 383s 6s/step - loss: 0.6481 - accuracy: 0.6463 - val_loss: 0.5457 - val_accuracy: 0.7750 - lr: 0.0100
# Epoch 2/50
# 64/64 [==============================] - 415s 7s/step - loss: 0.5341 - accuracy: 0.7355 - val_loss: 0.6342 - val_accuracy: 0.6438 - lr: 0.0100
# Epoch 3/50
# 64/64 [==============================] - 384s 6s/step - loss: 0.4892 - accuracy: 0.7684 - val_loss: 0.5778 - val_accuracy: 0.6500 - lr: 0.0100
# Epoch 4/50
# 64/64 [==============================] - 420s 7s/step - loss: 0.4748 - accuracy: 0.7731 - val_loss: 0.5412 - val_accuracy: 0.6687 - lr: 0.0100
# Epoch 5/50
# 64/64 [==============================] - 415s 7s/step - loss: 0.4052 - accuracy: 0.8232 - val_loss: 0.3869 - val_accuracy: 0.8500 - lr: 0.0100
# Epoch 6/50
# 64/64 [==============================] - 415s 7s/step - loss: 0.4021 - accuracy: 0.8200 - val_loss: 0.5708 - val_accuracy: 0.7125 - lr: 0.0100
# Epoch 7/50
# 64/64 [==============================] - 405s 6s/step - loss: 0.3537 - accuracy: 0.8419 - val_loss: 0.4171 - val_accuracy: 0.8062 - lr: 0.0100
# Epoch 8/50
# 64/64 [==============================] - 389s 6s/step - loss: 0.3371 - accuracy: 0.8388 - val_loss: 0.3410 - val_accuracy: 0.8750 - lr: 0.0100
# Epoch 9/50
# 64/64 [==============================] - 537s 8s/step - loss: 0.3246 - accuracy: 0.8717 - val_loss: 0.5470 - val_accuracy: 0.7125 - lr: 0.0100
# Epoch 10/50
# 64/64 [==============================] - 3102s 49s/step - loss: 0.3205 - accuracy: 0.8466 - val_loss: 0.3708 - val_accuracy: 0.8375 - lr: 0.0100
# Epoch 11/50
# 64/64 [==============================] - 451s 7s/step - loss: 0.3346 - accuracy: 0.8560 - val_loss: 0.3442 - val_accuracy: 0.8375 - lr: 0.0100
# Epoch 12/50
# 64/64 [==============================] - 423s 7s/step - loss: 0.3394 - accuracy: 0.8545 - val_loss: 0.3255 - val_accuracy: 0.8625 - lr: 0.0100
# Epoch 13/50
# 64/64 [==============================] - 414s 6s/step - loss: 0.2947 - accuracy: 0.8638 - val_loss: 0.4062 - val_accuracy: 0.8188 - lr: 0.0100
# Epoch 14/50
# 64/64 [==============================] - 406s 6s/step - loss: 0.3186 - accuracy: 0.8701 - val_loss: 0.3440 - val_accuracy: 0.8625 - lr: 0.0100
# Epoch 15/50
# 64/64 [==============================] - 425s 7s/step - loss: 0.2409 - accuracy: 0.9124 - val_loss: 0.8184 - val_accuracy: 0.6187 - lr: 0.0100
# Epoch 16/50
# 64/64 [==============================] - 455s 7s/step - loss: 0.2381 - accuracy: 0.8967 - val_loss: 0.4923 - val_accuracy: 0.7250 - lr: 0.0100
# Epoch 17/50
# 64/64 [==============================] - 467s 7s/step - loss: 0.2292 - accuracy: 0.9124 - val_loss: 0.3084 - val_accuracy: 0.8875 - lr: 0.0100
# Epoch 18/50
# 64/64 [==============================] - 480s 8s/step - loss: 0.2682 - accuracy: 0.9077 - val_loss: 0.4244 - val_accuracy: 0.8062 - lr: 0.0100
# Epoch 19/50
# 64/64 [==============================] - 379s 6s/step - loss: 0.2500 - accuracy: 0.9092 - val_loss: 0.3463 - val_accuracy: 0.8500 - lr: 0.0100
# Epoch 20/50
# 64/64 [==============================] - 409s 6s/step - loss: 0.2524 - accuracy: 0.8983 - val_loss: 0.2951 - val_accuracy: 0.8813 - lr: 0.0100
# Epoch 21/50
# 64/64 [==============================] - 400s 6s/step - loss: 0.2217 - accuracy: 0.9061 - val_loss: 0.3453 - val_accuracy: 0.8438 - lr: 0.0100
# Epoch 22/50
# 64/64 [==============================] - 399s 6s/step - loss: 0.1940 - accuracy: 0.9155 - val_loss: 0.3127 - val_accuracy: 0.8750 - lr: 0.0100
# Epoch 23/50
# 64/64 [==============================] - 401s 6s/step - loss: 0.2263 - accuracy: 0.9124 - val_loss: 0.5701 - val_accuracy: 0.7500 - lr: 0.0100
# Epoch 24/50
# 64/64 [==============================] - 400s 6s/step - loss: 0.2630 - accuracy: 0.8858 - val_loss: 0.4112 - val_accuracy: 0.8188 - lr: 0.0100
# Epoch 25/50
# 64/64 [==============================] - ETA: 0s - loss: 0.2431 - accuracy: 0.9061
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.005999999865889549.
# 64/64 [==============================] - 399s 6s/step - loss: 0.2431 - accuracy: 0.9061 - val_loss: 0.3053 - val_accuracy: 0.8938 - lr: 0.0100
# Epoch 26/50
# 64/64 [==============================] - 401s 6s/step - loss: 0.1325 - accuracy: 0.9546 - val_loss: 0.3271 - val_accuracy: 0.8625 - lr: 0.0060
# Epoch 27/50
# 64/64 [==============================] - 403s 6s/step - loss: 0.1173 - accuracy: 0.9577 - val_loss: 0.2913 - val_accuracy: 0.8938 - lr: 0.0060
# Epoch 28/50
# 64/64 [==============================] - 407s 6s/step - loss: 0.1036 - accuracy: 0.9671 - val_loss: 0.3124 - val_accuracy: 0.8813 - lr: 0.0060
# Epoch 29/50
# 64/64 [==============================] - 415s 7s/step - loss: 0.0955 - accuracy: 0.9718 - val_loss: 0.3114 - val_accuracy: 0.8625 - lr: 0.0060
# Epoch 30/50
# 64/64 [==============================] - 413s 6s/step - loss: 0.0834 - accuracy: 0.9750 - val_loss: 0.3071 - val_accuracy: 0.8875 - lr: 0.0060
# Epoch 31/50
# 64/64 [==============================] - 408s 6s/step - loss: 0.1078 - accuracy: 0.9624 - val_loss: 0.4729 - val_accuracy: 0.8313 - lr: 0.0060
# Epoch 32/50
# 64/64 [==============================] - ETA: 0s - loss: 0.1037 - accuracy: 0.9687
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.003600000031292438.
# 64/64 [==============================] - 409s 6s/step - loss: 0.1037 - accuracy: 0.9687 - val_loss: 0.3036 - val_accuracy: 0.8938 - lr: 0.0060
# Epoch 33/50
# 64/64 [==============================] - 408s 6s/step - loss: 0.0478 - accuracy: 0.9859 - val_loss: 0.2943 - val_accuracy: 0.8875 - lr: 0.0036
# Epoch 34/50
# 64/64 [==============================] - 408s 6s/step - loss: 0.0382 - accuracy: 0.9890 - val_loss: 0.3070 - val_accuracy: 0.8813 - lr: 0.0036
# Epoch 35/50
# 64/64 [==============================] - 408s 6s/step - loss: 0.0387 - accuracy: 0.9922 - val_loss: 0.2798 - val_accuracy: 0.9062 - lr: 0.0036
# Epoch 36/50
# 64/64 [==============================] - 376s 6s/step - loss: 0.0355 - accuracy: 0.9890 - val_loss: 0.2976 - val_accuracy: 0.8938 - lr: 0.0036
# Epoch 37/50
# 64/64 [==============================] - 410s 6s/step - loss: 0.0349 - accuracy: 0.9875 - val_loss: 0.2935 - val_accuracy: 0.8875 - lr: 0.0036
# Epoch 38/50
# 64/64 [==============================] - 405s 6s/step - loss: 0.0220 - accuracy: 0.9984 - val_loss: 0.3198 - val_accuracy: 0.8938 - lr: 0.0036
# Epoch 39/50
# 64/64 [==============================] - 409s 6s/step - loss: 0.0223 - accuracy: 0.9969 - val_loss: 0.2957 - val_accuracy: 0.9062 - lr: 0.0036
# Epoch 40/50
# 64/64 [==============================] - ETA: 0s - loss: 0.0173 - accuracy: 0.9984
# Epoch 40: ReduceLROnPlateau reducing learning rate to 0.0021599999628961085.
# 64/64 [==============================] - 406s 6s/step - loss: 0.0173 - accuracy: 0.9984 - val_loss: 0.3132 - val_accuracy: 0.9062 - lr: 0.0036
# Epoch 41/50
# 64/64 [==============================] - 414s 6s/step - loss: 0.0136 - accuracy: 1.0000 - val_loss: 0.3385 - val_accuracy: 0.8813 - lr: 0.0022
# Epoch 42/50
# 64/64 [==============================] - 419s 7s/step - loss: 0.0129 - accuracy: 1.0000 - val_loss: 0.3095 - val_accuracy: 0.9062 - lr: 0.0022
# Epoch 43/50
# 64/64 [==============================] - 418s 7s/step - loss: 0.0130 - accuracy: 1.0000 - val_loss: 0.3129 - val_accuracy: 0.9125 - lr: 0.0022
# Epoch 44/50
# 64/64 [==============================] - 418s 7s/step - loss: 0.0115 - accuracy: 1.0000 - val_loss: 0.3112 - val_accuracy: 0.9062 - lr: 0.0022
# Epoch 45/50
# 64/64 [==============================] - ETA: 0s - loss: 0.0110 - accuracy: 1.0000
# Epoch 45: ReduceLROnPlateau reducing learning rate to 0.0012959999497979878.
# 64/64 [==============================] - 407s 6s/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 0.3190 - val_accuracy: 0.9062 - lr: 0.0022
# Epoch 46/50
# 64/64 [==============================] - 1394s 22s/step - loss: 0.0099 - accuracy: 1.0000 - val_loss: 0.3196 - val_accuracy: 0.9125 - lr: 0.0013
# Epoch 47/50
# 64/64 [==============================] - 394s 6s/step - loss: 0.0095 - accuracy: 1.0000 - val_loss: 0.3164 - val_accuracy: 0.9125 - lr: 0.0013
# Epoch 48/50
# 64/64 [==============================] - 418s 7s/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.3173 - val_accuracy: 0.9125 - lr: 0.0013
# Epoch 49/50
# 64/64 [==============================] - 430s 7s/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.3190 - val_accuracy: 0.9125 - lr: 0.0013
# Epoch 50/50
# 64/64 [==============================] - ETA: 0s - loss: 0.0081 - accuracy: 1.0000
# Epoch 50: ReduceLROnPlateau reducing learning rate to 0.0007775999838486314.
# 64/64 [==============================] - 451s 7s/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.3186 - val_accuracy: 0.9125 - lr: 0.0013

# %%
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Assuming `predicted_labels` are the predictions of model on the test set
predicted_labels = []
batch_size = 8  # Further reduce this value based on GPU's memory
for i in range(0, features_test.shape[0], batch_size):
    batch_predictions = vgg16_model.predict(features_test[i:i+batch_size], verbose=0)
    batch_predictions = np.argmax(batch_predictions, axis=1)
    predicted_labels.extend(batch_predictions)

predicted_labels = np.array(predicted_labels)
true_labels = np.argmax(labels_test, axis=1)

# Classification Report
print("\nClassification Report of VGG16:")
print(classification_report(true_labels, predicted_labels))

# Confusion Matrix
conf_mat = confusion_matrix(true_labels, predicted_labels)
print("\nConfusion Matrix of VGG16:")
# print(conf_mat)

# Heatmap for Confusion Matrix
plt.figure(figsize=(10,7))
sns.heatmap(conf_mat, annot=True)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# ROC Curve
fpr, tpr, _ = roc_curve(true_labels, predicted_labels)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve of VGG16')
plt.legend(loc="lower right")
plt.show()
# Out:
# Classification Report of VGG16:
#               precision    recall  f1-score   support
#
#            0       0.85      0.88      0.86        94
#            1       0.89      0.86      0.88       106
#
#     accuracy                           0.87       200
#    macro avg       0.87      0.87      0.87       200
# weighted avg       0.87      0.87      0.87       200
#
#
# Confusion Matrix of VGG16:

# %%
plt.figure(figsize=[6,4])
plt.plot(history.history['loss'], 'black', linewidth=2.0)
plt.plot(history.history['val_loss'], 'blue', linewidth=2.0)
plt.legend(['Training Loss', 'Validation Loss'], fontsize=14)
plt.xlabel('Epochs', fontsize=10)
plt.ylabel('Loss', fontsize=10)
plt.title('Loss Curves of VGG16', fontsize=12)
plt.show()
